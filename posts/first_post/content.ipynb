# %% [markdown]
# # The simplest notebook.
#
# mathjax test... $\frac{1}{2}$
#
# $x^2+2x+1$

# %%
print("Hello, IPython")
# Out:
# Hello, IPython

# %%
li = [1,2,3,4,5]

# %%
import matplotlib.pyplot as plt

plt.plot(li)
plt.show()

# %% [markdown]
# Bacon ipsum dolor amet beef chislic alcatra frankfurter turkey capicola. Brisket frankfurter t-bone venison. Strip steak turducken prosciutto picanha. Beef ribs picanha pork boudin pork chop chislic bacon landjaeger chicken jowl t-bone brisket kielbasa cupim. Corned beef pancetta pork turkey, cow pig venison rump jerky strip steak picanha shoulder pork loin cupim. Tail capicola burgdoggen cow kielbasa. Shankle kielbasa venison ham, pig tenderloin meatloaf chislic picanha bresaola.
#
# Drumstick tri-tip shankle leberkas ground round biltong. Biltong capicola short ribs, jowl cupim pork venison. Rump turducken brisket turkey filet mignon pork. Corned beef sirloin bresaola tongue cupim cow ground round short loin chicken.
#
# Tail kevin corned beef landjaeger jowl. Salami venison shank ham, beef frankfurter cupim pancetta brisket meatball. Short ribs ham rump, tail buffalo fatback pork chop jowl alcatra short loin meatloaf swine shank turducken beef ribs. Ground round landjaeger salami boudin pork chop jowl beef ribs, porchetta brisket. Frankfurter salami pig tri-tip jerky filet mignon ribeye short ribs hamburger capicola swine cow andouille. Ham hock cow pork loin turducken meatloaf.
#
# Hamburger doner shankle chicken short loin. Biltong cow spare ribs shankle chicken tenderloin. Sausage landjaeger meatball, swine turkey kielbasa hamburger biltong tri-tip bresaola. Leberkas spare ribs pancetta, tail brisket kielbasa doner filet mignon drumstick frankfurter ham. Pastrami fatback swine chicken, porchetta pork loin andouille corned beef spare ribs.
#
# Turkey filet mignon drumstick turducken pork loin buffalo landjaeger short ribs corned beef andouille capicola brisket burgdoggen ham pastrami. Ball tip drumstick tongue, pancetta chicken beef ribs pork tail filet mignon beef. Cow picanha meatball, sirloin tri-tip pancetta kevin beef ribs ball tip. Burgdoggen tri-tip filet mignon t-bone jowl rump buffalo turkey ham chuck leberkas. Tail hamburger rump meatball drumstick turkey, prosciutto pork chop kevin boudin jerky pork belly. Cupim turducken ham cow, shankle biltong swine.

# %%
import random

li = [random.random()*10 for x in range(10)]
plt.plot(li)
plt.show()
